# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Dell\Downloads\lockdownindiawarningzones.csv')
df.set_index('S.no',inplace=True)
df
# Out:
#                       District                        State        Zone
# S.no
# 1               South Andamans  Andaman And Nicobar Islands    Red Zone
# 2                     Nicobars  Andaman And Nicobar Islands  Green Zone
# 3     North And Middle Andaman  Andaman And Nicobar Islands  Green Zone
# 4                      Kurnool               Andhra Pradesh    Red Zone
# 5                       Guntur               Andhra Pradesh    Red Zone
# ...                        ...                          ...         ...
# 729                 Coochbehar                  West Bengal  Green Zone
# 730           Dinajpur Dakshin                  West Bengal  Green Zone
# 731                    Purulia                  West Bengal  Green Zone
# 732                 Alipurduar                  West Bengal  Green Zone
# 733                   Jhargram                  West Bengal  Green Zone
#
# [733 rows x 3 columns]

# %%
x = df.Zone

# %%
plt.hist(x,bins=10,align='left')
plt.xlabel('Contamination Zone',labelpad = 20,fontsize = 'medium')
plt.ylabel('Frequency of Zones',labelpad = 20,fontsize='medium')
plt.title('covid-19 india contamination zones',pad=20,fontsize='xx-large')
plt.show()

# %%
x1 = df.Zone
y1 = df.State

# %%
fig = plt.figure(figsize=(15,15),facecolor='green')
plt.plot(x1,y1,marker='o',markerfacecolor='g')
plt.xlabel('States',labelpad = 20,fontsize = 'x-large')
plt.ylabel('Contamination zones',labelpad = 20,fontsize='x-large')
plt.title('covid-19 india contamination zones',pad=20,fontsize='xx-large')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(8,13),facecolor='orange')
plt.scatter(x1,y1,marker='o')
plt.xlabel('Contamination Zone',labelpad = 20,fontsize = 'medium')
plt.ylabel('Frequency of Zones',labelpad = 20,fontsize='medium')
plt.title('covid-19 india contamination zones',pad=20,fontsize='xx-large')
plt.show()

# %%
## Plotting for first 20 rows to avoid clumpsyness
data = df.head(20)
x_data = data.Zone
y_data = data.District

# %%
fig = plt.figure(figsize(9,13))
plt.plot(x_data,y_data,marker='o',markerfacecolor='g')
plt.xlabel('States',labelpad = 20,fontsize = 'x-large')
plt.ylabel('Contamination zones',labelpad = 20,fontsize='x-large')
plt.title('covid-19 india contamination zones',pad=20,fontsize='xx-large')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-6c941a9ecb98> in <module>
# ----> 1 fig = plt.figure(figsize(9,13))
#       2 plt.plot(x_data,y_data,marker='o',markerfacecolor='g')
#       3 plt.xlabel('States',labelpad = 20,fontsize = 'x-large')
#       4 plt.ylabel('Contamination zones',labelpad = 20,fontsize='x-large')
#       5 plt.title('covid-19 india contamination zones',pad=20,fontsize='xx-large')
#
# NameError: name 'figsize' is not defined

# %%
x = data.Zone
y = data.District

# %%
plt.scatter(x,y,marker='*',facecolor='g')
plt.xlabel('States',labelpad = 20,fontsize = 'x-large')
plt.ylabel('Contamination zones',labelpad = 20,fontsize='x-large')
plt.title('covid-19 india contamination zones',pad=20,fontsize='xx-large')
plt.show()

# %%
# Remark : Bar Graph , Pie-Char , Box-Plot require atleast one numerical
